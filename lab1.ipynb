# %%
print ("hello neju")
# Out:
# hello neju

# %%
x=5
if x<10:
    print ("it is true")
# Out:
# it is true

# %%
x=10
if x>10:
   print ("oh loard")
elif x<20:
   print ("it is right")
# Out:
# it is right

# %%
for i in range(1,10):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
name =input("enter ur name:")
print ("hello",name)
# Out:
# enter ur name: neju
# hello neju

# %%
#tuple
data =(1,2,3,4,5)

# %%
data
# Out:
# (1, 2, 3, 4, 5)

# %%
#list
data =[1,2,3,4,5]

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
del data[2]

# %%
data
# Out:
# [1, 2, 5]

# %%
data.append
# Out:
# <function list.append(object, /)>

# %%
data
# Out:
# [1, 2, 5]

# %%
data.append (3)

# %%
data
# Out:
# [1, 2, 5, 3]

# %%
data [3]=12

# %%
data
# Out:
# [1, 2, 5, 12]

# %%
data.pop()
# Out:
# 12

# %%
language =["c++","java","oop","python"]

# %%
for i in (language):
 print(i)
# Out:
# c++
# java
# oop
# python

# %%
language [-1]
# Out:
# 'python'

# %%
x=6
for i in range(x):
  spaces=" "*(x-i-1)
  stars="*" *(2*i+1)
  print (spaces+stars)
for i in range(x):
  spaces=" "*(x-i-1)
  stars="*" *(2*i+1)
  print (spaces+stars)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
#      *
#     ***
#    *****
#   *******
#  *********
# ***********

# %%
text = "The blank page always presents a daunting challenge to any aspiring writer. You sit at your desk and stare at the blinking cursor for what feels like hours. Ideas swirl around in your head, but they refuse to land gracefully on the screen. It takes a deep breath and a sudden burst of courage to type that very first word. Once the initial barrier is broken, the momentum slowly begins to shift in your favor. Each subsequent sentence builds upon the last, constructing a fragile bridge of thought. You find yourself diving deeper into the imaginary world you are actively creating. Words begin to flow like a river that has finally breached its dam. Writing is rarely easy, but the breakthrough makes the struggle entirely worthwhile."

# %%
print (text)
# Out:
# The blank page always presents a daunting challenge to any aspiring writer. You sit at your desk and stare at the blinking cursor for what feels like hours. Ideas swirl around in your head, but they refuse to land gracefully on the screen. It takes a deep breath and a sudden burst of courage to type that very first word. Once the initial barrier is broken, the momentum slowly begins to shift in your favor. Each subsequent sentence builds upon the last, constructing a fragile bridge of thought. You find yourself diving deeper into the imaginary world you are actively creating. Words begin to flow like a river that has finally breached its dam. Writing is rarely easy, but the breakthrough makes the struggle entirely worthwhile.

# %%
text.split()
# Out:
# ['The',
#  'blank',
#  'page',
#  'always',
#  'presents',
#  'a',
#  'daunting',
#  'challenge',
#  'to',
#  'any',
#  'aspiring',
#  'writer.',
#  'You',
#  'sit',
#  'at',
#  'your',
#  'desk',
#  'and',
#  'stare',
#  'at',
#  'the',
#  'blinking',
#  'cursor',
#  'for',
#  'what',
#  'feels',
#  'like',
#  'hours.',
#  'Ideas',
#  'swirl',
#  'around',
#  'in',
#  'your',
#  'head,',
#  'but',
#  'they',
#  'refuse',
#  'to',
#  'land',
#  'gracefully',
#  'on',
#  'the',
#  'screen.',
#  'It',
#  'takes',
#  'a',
#  'deep',
#  'breath',
#  'and',
#  'a',
#  'sudden',
#  'burst',
#  'of',
#  'courage',
#  'to',
#  'type',
#  'that',
#  'very',
#  'first',
#  'word.',
#  'Once',
#  'the',
#  'initial',
#  'barrier',
#  'is',
#  'broken,',
#  'the',
#  'momentum',
#  'slowly',
#  'begins',
#  'to',
#  'shift',
#  'in',
#  'your',
#  'favor.',
#  'Each',
#  'subsequent',
#  'sentence',
#  'builds',
#  'upon',
#  'the',
#  'last,',
#  'constructing',
#  'a',
#  'fragile',
# ...

# %%
text.lower().split()
# Out:
# ['the',
#  'blank',
#  'page',
#  'always',
#  'presents',
#  'a',
#  'daunting',
#  'challenge',
#  'to',
#  'any',
#  'aspiring',
#  'writer.',
#  'you',
#  'sit',
#  'at',
#  'your',
#  'desk',
#  'and',
#  'stare',
#  'at',
#  'the',
#  'blinking',
#  'cursor',
#  'for',
#  'what',
#  'feels',
#  'like',
#  'hours.',
#  'ideas',
#  'swirl',
#  'around',
#  'in',
#  'your',
#  'head,',
#  'but',
#  'they',
#  'refuse',
#  'to',
#  'land',
#  'gracefully',
#  'on',
#  'the',
#  'screen.',
#  'it',
#  'takes',
#  'a',
#  'deep',
#  'breath',
#  'and',
#  'a',
#  'sudden',
#  'burst',
#  'of',
#  'courage',
#  'to',
#  'type',
#  'that',
#  'very',
#  'first',
#  'word.',
#  'once',
#  'the',
#  'initial',
#  'barrier',
#  'is',
#  'broken,',
#  'the',
#  'momentum',
#  'slowly',
#  'begins',
#  'to',
#  'shift',
#  'in',
#  'your',
#  'favor.',
#  'each',
#  'subsequent',
#  'sentence',
#  'builds',
#  'upon',
#  'the',
#  'last,',
#  'constructing',
#  'a',
#  'fragile',
# ...

# %%
len(sorted (text.lower().split()))
# Out:
# 126

# %%
sorted (text.lower().split())
# Out:
# ['a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'actively',
#  'always',
#  'and',
#  'and',
#  'any',
#  'are',
#  'around',
#  'aspiring',
#  'at',
#  'at',
#  'barrier',
#  'begin',
#  'begins',
#  'blank',
#  'blinking',
#  'breached',
#  'breakthrough',
#  'breath',
#  'bridge',
#  'broken,',
#  'builds',
#  'burst',
#  'but',
#  'but',
#  'challenge',
#  'constructing',
#  'courage',
#  'creating.',
#  'cursor',
#  'dam.',
#  'daunting',
#  'deep',
#  'deeper',
#  'desk',
#  'diving',
#  'each',
#  'easy,',
#  'entirely',
#  'favor.',
#  'feels',
#  'finally',
#  'find',
#  'first',
#  'flow',
#  'for',
#  'fragile',
#  'gracefully',
#  'has',
#  'head,',
#  'hours.',
#  'ideas',
#  'imaginary',
#  'in',
#  'in',
#  'initial',
#  'into',
#  'is',
#  'is',
#  'it',
#  'its',
#  'land',
#  'last,',
#  'like',
#  'like',
#  'makes',
#  'momentum',
#  'of',
#  'of',
#  'on',
#  'once',
#  'page',
#  'presents',
#  'rarely',
#  'refuse',
#  'river',
#  'screen.',
#  'sentence',
# ...

# %%
word_count= text.lower().replace(",","").split().count("a")

# %%
print (word_count)
# Out:
# 5

# %%
word_count= text.lower().replace(",","").split()

# %%
print (word_count)
# Out:
# ['the', 'blank', 'page', 'always', 'presents', 'a', 'daunting', 'challenge', 'to', 'any', 'aspiring', 'writer.', 'you', 'sit', 'at', 'your', 'desk', 'and', 'stare', 'at', 'the', 'blinking', 'cursor', 'for', 'what', 'feels', 'like', 'hours.', 'ideas', 'swirl', 'around', 'in', 'your', 'head', 'but', 'they', 'refuse', 'to', 'land', 'gracefully', 'on', 'the', 'screen.', 'it', 'takes', 'a', 'deep', 'breath', 'and', 'a', 'sudden', 'burst', 'of', 'courage', 'to', 'type', 'that', 'very', 'first', 'word.', 'once', 'the', 'initial', 'barrier', 'is', 'broken', 'the', 'momentum', 'slowly', 'begins', 'to', 'shift', 'in', 'your', 'favor.', 'each', 'subsequent', 'sentence', 'builds', 'upon', 'the', 'last', 'constructing', 'a', 'fragile', 'bridge', 'of', 'thought.', 'you', 'find', 'yourself', 'diving', 'deeper', 'into', 'the', 'imaginary', 'world', 'you', 'are', 'actively', 'creating.', 'words', 'begin', 'to', 'flow', 'like', 'a', 'river', 'that', 'has', 'finally', 'breached', 'its', 'dam.', 'writin
# ...

# %%
dect{}
for i in word
if i =

# %%
file=open ("multi.txt","a")
for data in text:
 file_data = str(data)+"\t"+str(data**1)+"\t"+str(data**2)+"\t"+str(data**2)+"\t"+str(data**3)
    file_data.write 
 print (file_data)
# Out:
# 1	1	1	1	1
# 2	2	4	4	8
# 3	3	9	9	27
# 4	4	16	16	64
# 5	5	25	25	125
# 6	6	36	36	216
# 7	7	49	49	343
# 8	8	64	64	512
# 9	9	81	81	729

# %%
numbers = [1, 2, 3, 4, 5]

results = [n * 2 + n // 2 for n in numbers]

print(results)
# Out:
# [2, 5, 7, 10, 12]

# %%
for n in numbers:
    result = n * 2 + n / 2

    if result % 2 == 0:
        print(result)
# Out:
# 10.0
